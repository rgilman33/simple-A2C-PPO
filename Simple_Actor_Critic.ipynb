# %%
import argparse
import gym
import numpy as np
from itertools import count
from collections import namedtuple

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable


class args:
    def __init__(self):
        self.seed = 1
        self.gamma = .99
        self.render = False
        self.log_interval = 50

args = args()
        
env = gym.make('CartPole-v0')
env.seed(args.seed)
torch.manual_seed(args.seed)

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.affine1 = nn.Linear(4, 128)
        self.action_head = nn.Linear(128, 2)
        self.value_head = nn.Linear(128, 1)

        self.actions = []
        self.action_log_probs = []
        self.entropies = []
        self.state_values = []
        self.rewards = []
        

    def forward(self, x):
        x = F.relu(self.affine1(x))
        action_scores = self.action_head(x)
        state_values = self.value_head(x)
        return F.softmax(action_scores), state_values


model = Policy()
optimizer = optim.Adam(model.parameters(), lr=3e-2)

def select_action(state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    
    probs, state_value = model(Variable(state))
    action = probs.multinomial().data[0][0]
    
    prob = probs[:, action].view(1, -1)
    action_log_prob = prob.log()
    entropy = - (probs*probs.log()).sum()
    
    return action, action_log_prob, entropy, state_value

# %%
running_reward = 10
for i_episode in count(1):
    state = env.reset()
    for t in range(1000): # Don't infinite loop while learning
        action, action_log_prob, entropy, state_value = select_action(state)
        #print(action)
        state, reward, done, _ = env.step(action)
        #print(state, reward)

        model.rewards.append(reward)
        model.actions.append(action)
        model.action_log_probs.append(action_log_prob)
        model.entropies.append(entropy)
        model.state_values.append(state_value)
        
        if done:
            break

    running_reward = running_reward * 0.99 + t * 0.01
    
    #########################
    # Finish episode
    R = 0
    value_loss = 0
    rewards = []
    for r in model.rewards[::-1]:
        R = r + args.gamma * R
        rewards.insert(0, R)
        
        loss = loss - (model.action_log_probs[i]\
                       *(Variable(R).expand_as(log_probs[i])).cuda()).sum()\
            - (0.0001*entropies[i].cuda()).sum()
    
    global advantages, value_loss, action_gain
    
    advantages = Variable(torch.FloatTensor(rewards), requires_grad=True)
    - Variable(torch.FloatTensor([i.data[0][0] for i in model.state_values]), requires_grad=True)
    
    value_loss = advantages.pow(2).mean()
    action_gain = (advantages *\
                   Variable(torch.FloatTensor([i.data[0][0] for i in model.action_log_probs]), requires_grad=True)).mean()
    
    total_loss = value_loss\
    - action_gain - Variable(torch.FloatTensor([i.data[0] for i in model.entropies]), requires_grad=True).mean()
    optimizer.zero_grad()
    
    total_loss.backward()
    
    optimizer.step()
    del model.rewards[:]
    del model.actions[:]
    del model.action_log_probs[:]
    del model.entropies[:]
    del model.state_values[:]
    ########################################
    
    if i_episode % args.log_interval == 0:
        print('Episode {}\tLast length: {:5d}\tAverage length: {:.2f}'.format(
            i_episode, t, running_reward))
    if running_reward > env.spec.reward_threshold:
        print("Solved! Running reward is now {} and "
              "the last episode runs to {} time steps!".format(running_reward, t))
        break
# Out:
# <ipython-input-103-4de3e32da216>:31: SyntaxWarning: name 'value_loss' is assigned to before global declaration
#   global advantages, value_loss, action_gain
# Episode 50	Last length:    17	Average length: 15.17
# Episode 100	Last length:    19	Average length: 17.16
# Episode 150	Last length:    17	Average length: 19.06
# Episode 200	Last length:    13	Average length: 19.94
# Episode 250	Last length:    16	Average length: 20.62
# Episode 300	Last length:    36	Average length: 20.64
# Episode 350	Last length:    15	Average length: 19.83
# Episode 400	Last length:    28	Average length: 20.71
# Episode 450	Last length:    26	Average length: 20.71
# Episode 500	Last length:    12	Average length: 20.69
# Episode 550	Last length:    39	Average length: 20.65
# Episode 600	Last length:    19	Average length: 20.95
# Episode 650	Last length:    16	Average length: 21.16
# Episode 700	Last length:    46	Average length: 21.23
# Episode 750	Last length:    27	Average length: 21.91
# Episode 800	Last length:    28	Average length: 21.77
# Episode 850	Last length:    12	Average length: 21.56
# Episode 900	Last length:    19	Average length: 21.87
# Episode 950	Last length:    21	Average length: 20.78
# Episode 1000	Last length:    11	Average length: 20.92
# Episode 1050	Last length:    14	Average length: 21.47
# Episode 1100	Last length:    19	Average length: 19.49
# Episode 1150	Last length:    27	Average length: 20.43
# Episode 1200	Last length:    10	Average length: 20.38
# Episode 1250	Last length:    16	Average length: 20.22
# Episode 1300	Last length:    10	Average length: 20.49
# Episode 1350	Last length:    17	Average length: 21.47
# Episode 1400	Last length:    33	Average length: 21.27
# Episode 1450	Last length:    15	Average length: 20.21
# Episode 1500	Last length:    43	Average length: 20.62
# Episode 1550	Last length:     9	Average length: 20.12
# Episode 1600	Last length:    10	Average length: 19.87
# Episode 1650	Last length:    21	Average length: 20.28
# Episode 1700	Last length:    11	Average length: 21.23
# Episode 1750	Last length:     9	Average length: 22.18
# Episode 1800	Last length:     9	Average length: 22.34
# Episode 1850	Last length:    31	Average length: 21.83
# Episode 1900	Last length:    21	Average length: 21.58
# Episode 1950	Last length:    20	Average length: 21.44
# Episode 2000	Last length:    50	Average length: 23.14
# Episode 2050	Last length:    14	Average length: 23.39
# Episode 2100	Last length:    31	Average length: 22.88
# Episode 2150	Last length:    21	Average length: 22.60
# Episode 2200	Last length:    26	Average length: 22.75
# Episode 2250	Last length:    21	Average length: 23.25
# Episode 2300	Last length:    19	Average length: 22.24
# Episode 2350	Last length:    11	Average length: 21.28
# Episode 2400	Last length:    15	Average length: 20.48
# Episode 2450	Last length:    31	Average length: 21.12
# Episode 2500	Last length:    30	Average length: 21.87
# Episode 2550	Last length:    35	Average length: 22.28
# Episode 2600	Last length:    30	Average length: 21.59
# Episode 2650	Last length:    19	Average length: 21.36
# Episode 2700	Last length:    20	Average length: 21.39
# Episode 2750	Last length:    41	Average length: 21.75
# Episode 2800	Last length:    47	Average length: 21.87
# Episode 2850	Last length:    20	Average length: 21.74
# Episode 2900	Last length:    15	Average length: 21.07
# Episode 2950	Last length:    41	Average length: 22.12
# Episode 3000	Last length:    47	Average length: 21.77
# Episode 3050	Last length:    11	Average length: 22.39
# Episode 3100	Last length:    10	Average length: 21.06
# Episode 3150	Last length:    14	Average length: 20.96
# Episode 3200	Last length:    43	Average length: 22.53
# Episode 3250	Last length:    32	Average length: 21.32
# Episode 3300	Last length:    31	Average length: 20.89
# Episode 3350	Last length:    23	Average length: 20.73
# Episode 3400	Last length:    44	Average length: 21.73
# Episode 3450	Last length:    33	Average length: 22.83
# Episode 3500	Last length:    19	Average length: 22.05
# Episode 3550	Last length:    15	Average length: 22.77
# Episode 3600	Last length:     9	Average length: 22.72
# Episode 3650	Last length:    14	Average length: 22.16
# Episode 3700	Last length:    63	Average length: 23.27
# Episode 3750	Last length:    25	Average length: 21.95
# Episode 3800	Last length:    19	Average length: 22.30
# Episode 3850	Last length:    21	Average length: 21.20
# Episode 3900	Last length:    18	Average length: 21.74
# Episode 3950	Last length:    13	Average length: 22.81
# Episode 4000	Last length:    10	Average length: 22.32
# Episode 4050	Last length:     8	Average length: 22.99
# Episode 4100	Last length:    11	Average length: 22.20
# Episode 4150	Last length:    25	Average length: 23.06
# Episode 4200	Last length:    29	Average length: 22.39
# Episode 4250	Last length:    30	Average length: 20.96
# Episode 4300	Last length:    24	Average length: 20.97
# Episode 4350	Last length:    18	Average length: 21.64
# Episode 4400	Last length:    18	Average length: 21.55
# Episode 4450	Last length:    43	Average length: 21.16
# Episode 4500	Last length:    19	Average length: 21.23
# Episode 4550	Last length:    20	Average length: 21.91
# Episode 4600	Last length:    11	Average length: 22.12
# Episode 4650	Last length:    29	Average length: 21.98
# Episode 4700	Last length:    10	Average length: 21.02
# Episode 4750	Last length:    15	Average length: 21.84
# Episode 4800	Last length:   101	Average length: 22.75
# Episode 4850	Last length:    15	Average length: 22.68
# Episode 4900	Last length:    23	Average length: 22.55
# Episode 4950	Last length:    15	Average length: 21.75
# Episode 5000	Last length:    45	Average length: 22.12
# Episode 5050	Last length:    13	Average length: 21.98
# Episode 5100	Last length:    19	Average length: 21.14
# Episode 5150	Last length:    22	Average length: 22.07
# Episode 5200	Last length:    36	Average length: 23.37
# Episode 5250	Last length:    17	Average length: 22.30
# Episode 5300	Last length:    19	Average length: 23.29
# Episode 5350	Last length:    14	Average length: 22.91
# Episode 5400	Last length:    14	Average length: 22.71
# Episode 5450	Last length:    12	Average length: 20.63
# Episode 5500	Last length:    11	Average length: 19.81
# Episode 5550	Last length:    44	Average length: 20.18
# Episode 5600	Last length:    20	Average length: 20.57
# Episode 5650	Last length:    30	Average length: 21.87
# Episode 5700	Last length:    13	Average length: 22.14
# Episode 5750	Last length:    23	Average length: 22.01
# Episode 5800	Last length:    40	Average length: 21.76
# Episode 5850	Last length:    19	Average length: 21.52
# Episode 5900	Last length:    22	Average length: 21.95
# Episode 5950	Last length:    31	Average length: 21.68
# Episode 6000	Last length:    11	Average length: 22.15
# Episode 6050	Last length:    39	Average length: 21.71
# Episode 6100	Last length:    27	Average length: 22.84
# Episode 6150	Last length:    38	Average length: 22.66
# Episode 6200	Last length:    48	Average length: 23.07
# Episode 6250	Last length:    20	Average length: 22.43
# Episode 6300	Last length:    12	Average length: 22.25
# Episode 6350	Last length:    16	Average length: 22.96
# Episode 6400	Last length:    22	Average length: 22.50
# Episode 6450	Last length:    13	Average length: 22.33
# Episode 6500	Last length:    31	Average length: 23.00
# Episode 6550	Last length:    19	Average length: 22.71
# Episode 6600	Last length:    14	Average length: 21.75
# Episode 6650	Last length:    24	Average length: 22.49
# Episode 6700	Last length:    22	Average length: 22.36
# Episode 6750	Last length:    11	Average length: 21.91
# Episode 6800	Last length:    11	Average length: 20.48
# Episode 6850	Last length:    21	Average length: 20.02
# Episode 6900	Last length:    18	Average length: 20.42
# Episode 6950	Last length:    24	Average length: 21.17
# Episode 7000	Last length:    23	Average length: 21.13
# Episode 7050	Last length:    16	Average length: 21.57
# Episode 7100	Last length:    45	Average length: 23.53
# Episode 7150	Last length:    13	Average length: 22.10
# Episode 7200	Last length:    23	Average length: 20.76
# Episode 7250	Last length:    29	Average length: 21.46
# Episode 7300	Last length:    13	Average length: 21.38
# Episode 7350	Last length:    11	Average length: 21.62
# Episode 7400	Last length:    21	Average length: 23.21
# Episode 7450	Last length:    35	Average length: 22.39
# Episode 7500	Last length:    31	Average length: 21.54
# Episode 7550	Last length:    19	Average length: 21.45
# Episode 7600	Last length:    33	Average length: 20.70
# Episode 7650	Last length:    24	Average length: 20.74
# Episode 7700	Last length:    11	Average length: 21.31
# Episode 7750	Last length:    15	Average length: 22.07
# Episode 7800	Last length:    42	Average length: 22.32
# Episode 7850	Last length:    31	Average length: 24.42
# Episode 7900	Last length:    22	Average length: 24.67
# Episode 7950	Last length:    15	Average length: 22.80
# Episode 8000	Last length:    13	Average length: 22.21
# Episode 8050	Last length:    13	Average length: 21.58
# Episode 8100	Last length:    36	Average length: 21.33
# Episode 8150	Last length:    25	Average length: 20.28
# Episode 8200	Last length:    12	Average length: 21.76
# Episode 8250	Last length:    16	Average length: 22.70
# Episode 8300	Last length:    25	Average length: 21.95
# Episode 8350	Last length:    12	Average length: 21.28
# Episode 8400	Last length:    14	Average length: 22.12
# Episode 8450	Last length:    23	Average length: 22.78
# Episode 8500	Last length:    35	Average length: 22.67
# Episode 8550	Last length:    11	Average length: 22.86
# Episode 8600	Last length:    26	Average length: 22.25
# Episode 8650	Last length:    22	Average length: 21.43
# Episode 8700	Last length:    23	Average length: 23.43
# Episode 8750	Last length:    21	Average length: 22.90
# Episode 8800	Last length:    12	Average length: 22.57
# Episode 8850	Last length:    35	Average length: 22.74
# Episode 8900	Last length:    11	Average length: 22.26
# Episode 8950	Last length:    25	Average length: 22.79
# Episode 9000	Last length:    14	Average length: 22.67
# Episode 9050	Last length:     9	Average length: 21.34
# Episode 9100	Last length:    17	Average length: 23.69
# Episode 9150	Last length:    15	Average length: 21.92
# Episode 9200	Last length:    22	Average length: 22.74
# Episode 9250	Last length:    33	Average length: 21.67
# Episode 9300	Last length:    18	Average length: 21.95
# Episode 9350	Last length:    31	Average length: 22.79
# Episode 9400	Last length:    23	Average length: 22.32
# Episode 9450	Last length:     9	Average length: 21.54
# Episode 9500	Last length:    11	Average length: 21.42
# Episode 9550	Last length:    44	Average length: 21.23
# Episode 9600	Last length:    11	Average length: 21.10
# Episode 9650	Last length:    11	Average length: 21.66
# Episode 9700	Last length:    10	Average length: 21.42
# Episode 9750	Last length:    10	Average length: 21.05
# Episode 9800	Last length:    51	Average length: 21.30
# Episode 9850	Last length:    19	Average length: 22.30
# Episode 9900	Last length:    26	Average length: 21.84
# Episode 9950	Last length:    12	Average length: 21.85
# Episode 10000	Last length:    32	Average length: 22.73
# Episode 10050	Last length:    17	Average length: 21.57
# Episode 10100	Last length:    10	Average length: 21.94
# Episode 10150	Last length:    13	Average length: 21.59
# Episode 10200	Last length:    10	Average length: 22.49
# Episode 10250	Last length:    27	Average length: 22.39
# Episode 10300	Last length:    14	Average length: 22.04
# Episode 10350	Last length:    18	Average length: 21.70
# Episode 10400	Last length:    18	Average length: 22.37
# Episode 10450	Last length:    17	Average length: 20.87
# Episode 10500	Last length:    23	Average length: 21.85
# Episode 10550	Last length:    11	Average length: 21.27
# Episode 10600	Last length:    32	Average length: 21.27
# Episode 10650	Last length:    27	Average length: 22.05
# Episode 10700	Last length:    38	Average length: 20.54
# Episode 10750	Last length:    14	Average length: 20.82
# Episode 10800	Last length:    24	Average length: 23.07
# Episode 10850	Last length:    13	Average length: 22.20
# Episode 10900	Last length:    13	Average length: 22.17
# Episode 10950	Last length:    13	Average length: 21.85
# Episode 11000	Last length:    55	Average length: 22.72
# Episode 11050	Last length:    21	Average length: 23.06
# Episode 11100	Last length:    17	Average length: 21.63
# Episode 11150	Last length:    29	Average length: 21.06
# Episode 11200	Last length:    44	Average length: 21.88
# Episode 11250	Last length:    13	Average length: 22.26
# Episode 11300	Last length:    16	Average length: 22.26
# Episode 11350	Last length:    15	Average length: 22.67
# Episode 11400	Last length:     9	Average length: 21.92
# Episode 11450	Last length:    27	Average length: 22.12
# Episode 11500	Last length:    11	Average length: 22.14
# Episode 11550	Last length:    14	Average length: 21.81
# Episode 11600	Last length:    17	Average length: 21.77
# Episode 11650	Last length:     8	Average length: 22.80
# Episode 11700	Last length:    25	Average length: 22.57
# Episode 11750	Last length:    15	Average length: 21.59
# Episode 11800	Last length:    16	Average length: 21.51
# Episode 11850	Last length:    13	Average length: 20.94
# Episode 11900	Last length:    40	Average length: 22.06
# Episode 11950	Last length:    62	Average length: 22.94
# Episode 12000	Last length:    14	Average length: 23.34
# Episode 12050	Last length:     9	Average length: 21.10
# Episode 12100	Last length:     9	Average length: 21.19
# Episode 12150	Last length:    31	Average length: 20.85
# Episode 12200	Last length:    45	Average length: 22.98
# Episode 12250	Last length:    21	Average length: 23.00
# Episode 12300	Last length:    21	Average length: 21.79
# Episode 12350	Last length:    22	Average length: 20.78
# Episode 12400	Last length:    25	Average length: 20.51
# Episode 12450	Last length:    20	Average length: 20.43
# Episode 12500	Last length:    25	Average length: 20.31
# Episode 12550	Last length:    10	Average length: 20.40
# Episode 12600	Last length:    14	Average length: 20.30
# Episode 12650	Last length:    40	Average length: 21.19
# Episode 12700	Last length:    31	Average length: 22.72
# Episode 12750	Last length:    14	Average length: 21.68
# Episode 12800	Last length:    14	Average length: 22.44
# Episode 12850	Last length:     8	Average length: 22.99
# Episode 12900	Last length:    19	Average length: 22.09
# Episode 12950	Last length:    15	Average length: 22.65
# Episode 13000	Last length:    38	Average length: 24.43
# Episode 13050	Last length:    11	Average length: 23.44
# Episode 13100	Last length:    11	Average length: 23.60
# Episode 13150	Last length:    29	Average length: 22.49
# Episode 13200	Last length:    24	Average length: 22.32
# Episode 13250	Last length:    11	Average length: 21.59
# Episode 13300	Last length:    20	Average length: 20.74
# Episode 13350	Last length:    25	Average length: 23.00
# Episode 13400	Last length:    14	Average length: 21.62
# Episode 13450	Last length:    16	Average length: 22.66
# Episode 13500	Last length:    29	Average length: 21.46
# Episode 13550	Last length:    27	Average length: 22.02
# Episode 13600	Last length:    18	Average length: 21.77
# Episode 13650	Last length:    24	Average length: 21.96
# Episode 13700	Last length:    40	Average length: 22.38
# Episode 13750	Last length:    13	Average length: 21.98
# Episode 13800	Last length:    36	Average length: 22.20
# Episode 13850	Last length:     8	Average length: 22.00
# Episode 13900	Last length:    20	Average length: 22.39
# Episode 13950	Last length:    19	Average length: 23.21
# Episode 14000	Last length:    25	Average length: 22.98
# Episode 14050	Last length:    22	Average length: 21.61
# Episode 14100	Last length:    10	Average length: 22.21
# Episode 14150	Last length:    15	Average length: 21.90
# Episode 14200	Last length:    27	Average length: 21.86
# Episode 14250	Last length:    17	Average length: 21.27
# Episode 14300	Last length:    65	Average length: 21.73
# Episode 14350	Last length:    25	Average length: 21.55
# Episode 14400	Last length:    17	Average length: 21.77
# Episode 14450	Last length:    24	Average length: 22.66
# Episode 14500	Last length:    13	Average length: 22.17
# Episode 14550	Last length:    13	Average length: 20.68
# Episode 14600	Last length:    11	Average length: 20.76
# Episode 14650	Last length:    22	Average length: 21.85
# Episode 14700	Last length:     9	Average length: 22.28
# Episode 14750	Last length:    43	Average length: 23.50
# Episode 14800	Last length:    21	Average length: 24.45
# Episode 14850	Last length:    12	Average length: 23.22
# Episode 14900	Last length:    36	Average length: 22.40
# Episode 14950	Last length:    15	Average length: 22.51
# Episode 15000	Last length:    14	Average length: 22.52
# Episode 15050	Last length:    16	Average length: 22.88
# Episode 15100	Last length:    30	Average length: 22.74
# Episode 15150	Last length:    32	Average length: 21.92
# Episode 15200	Last length:    19	Average length: 21.77
# Episode 15250	Last length:    13	Average length: 21.55
# Episode 15300	Last length:    18	Average length: 22.72
# Episode 15350	Last length:    20	Average length: 23.29
# Episode 15400	Last length:    20	Average length: 22.26
# Episode 15450	Last length:    78	Average length: 21.28
# Episode 15500	Last length:    16	Average length: 21.79
# Episode 15550	Last length:    37	Average length: 22.56
# Episode 15600	Last length:    52	Average length: 21.34
# Episode 15650	Last length:    24	Average length: 20.88
# Episode 15700	Last length:    10	Average length: 21.57
# Episode 15750	Last length:    29	Average length: 20.84
# Episode 15800	Last length:    12	Average length: 20.79
# Episode 15850	Last length:    30	Average length: 21.54
# Episode 15900	Last length:    47	Average length: 22.26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-4de3e32da216> in <module>()
#       4     state = env.reset()
#       5     for t in range(1000): # Don't infinite loop while learning
# ----> 6         action, action_log_prob, entropy, state_value = select_action(state)
#       7         #print(action)
#       8         state, reward, done, _ = env.step(action)
#
# <ipython-input-102-90322472d4f4> in select_action(state)
#      29     action = probs.multinomial().data[0][0]
#      30
# ---> 31     prob = probs[:, action].view(1, -1)
#      32     action_log_prob = prob.log()
#      33     entropy = - (probs*probs.log()).sum()
#
# ~/.local/lib/python3.5/site-packages/torch/autograd/variable.py in __getitem__(self, key)
#      74                 return IndexSelect.apply(self, 0, key)
#      75             # else fall through and raise an error in Index
# ---> 76         return Index.apply(self, key)
#      77
#      78     def __setitem__(self, key, value):
#
# KeyboardInterrupt:

# %%
advantages
# Out:
# Variable containing:
#  22.1621
#  21.3444
#  20.5303
#  19.7040
#  18.8690
#  18.1379
#  17.3436
#  16.5237
#  15.6649
#  14.7808
#  13.9262
#  13.0271
#  12.1357
#  11.2294
#  10.3136
#   9.4931
#   8.5530
#   7.6574
#   6.6987
#   5.7394
#   4.8496
#   3.8581
#   2.8703
#   1.8782
#   0.8645
# [torch.FloatTensor of size 25]
